# %% [markdown]
#  # [![](https://img.shields.io/badge/Design-stablediffusion.vn-0075ff)](https://stablediffusion.vn) [![](https://img.shields.io/badge/Group-Support-0075ff)](https://www.facebook.com/groups/stablediffusion.vn) [![](https://img.shields.io/badge/Phiên%20bản-v1.8.18-0075ff)](https://stablediffusion.vn/update/) [![](https://img.shields.io/discord/813085864355037235?color=blue&label=Discord&logo=Discord)](https://discord.gg/5SEtApPeyG) [![](https://img.shields.io/badge/Donate-SDVN-green)](https://stablediffusion.vn/donate/)
#
# [![](https://img.shields.io/badge/Guide-Full-5858e6)](https://stablediffusion.vn/huong-dan-chung/) [![](https://img.shields.io/badge/Video-Youtube-E62117)](https://youtu.be/jcJTsmBmyJ0) [![](https://img.shields.io/badge/More-Tools-0075ff)](https://stablediffusion.vn/bo-cong-cu/) [![](https://img.shields.io/badge/Tools-Downloads-green)](https://colab.research.google.com/drive/1bbprkrT2gBb_JS8Noi3yxIEEFlV_PWw9#scrollTo=gAg03nKay-G8) [![](https://img.shields.io/badge/Check-Gradio%20Sever-orange)](https://status.gradio.app)
#
# ___
#
# ### 💡 Shortened link to use all the tools of SDVN : `sdvn.me`
# ### 💡 Basic Tutorial (Opens a hidden box to read):

# %% [markdown]
# ---
# ## 💡 User manual :
# *Some versions note:*
# - Version: All Versions can be used with SD1.5, SDXL only works with ComfyUI, SDXL, A1111-Update, only A1111-Update when running SDXL should have a colabpro account and use the included SDXLMode at part 2 to run with private settings
#
# - Option Prune : Helps to eliminate maximum resources to download, helping to install programs quickly
# - Extension Options : Help choosing Extensions to use for Versions A -
# - Option Controlnet : Will download the controlnet to use with all versions except SDXL (No controlnet can be used yet), but it will consume a lot of resources, please consider when choosing Extra
# - Option Setting : Contains options to update or reset settings, when encountering unexpected errors, try resetting settings
# - NoLibrary option : Will remove the download of additional library models, lora is available, if Prune is selected, this option is selected by default
# - Swapversion option: Will help to change the Version in use without interrupting the session, if unchecked, rerunning part one only loads more resources that are not available from the previous version
#
# - Option QRControlnet : Only works with Version A - Support downloading more controlnet, extension used during QR art creation
# - Option APIPhotoshop : Will help install more Extensions, making the link possible to use API with Photoshop
# - Comfy UI : Only works with Prune, Controlnet option
#
# ___
#
# + 1: Option to use version, option to add a model if there is no model available on the drive (These models only save to temporary memory, do not occupy the drive). In case there is no model, SDver1.5 will be automatically downloaded to colab.
# + 2 : **Ctr+F9** (Or at runtime => Run all)
# + 3 : Agree to "Still running" when warned
# + 4 : Agree to connect to the drive when asked
# + 5 : Wait 5-7 minutes until the program runs until the link appears in the result of part 2
# + 6 : Use a gradient link to access WebUI and use | Particularly for comfyUI Version, the link to use appears at the top of part 2 with the tail cloudflare.
# ---
# ## 💡 Installation instructions are to get API with Photoshop Extension :
#
# + Compatible with the latest PTS 2023 version
# + Install Extension : [GitHub](https://github.com/AbdullahAlfaraj/Auto-Photoshop-StableDiffusion-Plugin/releases/tag/v1.2.2) , Go to the link above, download the .zip or ccx file, extract it to the /Photoshop/Plugins folder and start PTS
# + Run the program until you receive the UI interface link (Currently ver2-16 version is fully compatible, ver2-23 version, ver2update may appear error)
# + Copy 1 of the links using the UI ( Cloudflare is preferred ) to the Extension ( setting section ) on PTS to use.
#
# ---
# ## 💡 Save data and download:
# - Save the optional model on the drive at the directory: /MyDrive/SD-Data/Model
# - Save the optional lora on the drive at the directory: /MyDrive/SD-Data/Lora
# - Save the optional textual on the drive at the directory: /MyDrive/SD-Data/Embeddings
# - Save wildcards for Dynamic Prompt : /MyDrive/SD-Data/wildcards
# - Save Hypernetworks on the drive at the directory: /MyDrive/SD-Data/Hypernetworks
# - Tools support downloading the model to the drive : [Download tools](https://colab.research.google.com/drive/1bbprkrT2gBb_JS8Noi3yxIEEFlV_PWw9#scrollTo=gAg03nKay-G8)
# ---
# ## 💡Note:
#
# 🚩 If the folder in the drive is not automatically recognized, please double check the path and account
#
# 🚩 If the GPU cannot be connected (The free GPU time of the day expires / The next day it will be restored), please change to another google account to use or upgrade pro
#
# 🚩 Share the SD-Data folder and create a path to my drive for another account if you want to share data and settings (Note the extra account if there is an SD-Data folder, delete it, just just show the shortcut of the main account)

# %% [markdown]
# # 🚀 StableDiffusion.VN

# %%
#@title # ⚙️ 1.Version options
#Cài môi trường
#@markdown <br> [![](https://img.shields.io/badge/Info-Version-blue)](https://bit.ly/42Csmn7)
Version = "A1111-update"  #@param ["ComfyUI","SDXL","Kohya","A-1.3","A-1.41","A1111-update"]
Extensions = "base"  #@param ["base","plus","video","train"]
Controlnet = "base"  #@param ["base","extra"]
Setting = "none" #@param ["none", "update" , "resetall"]

#@markdown <br> [![](https://img.shields.io/badge/Token-Ngrok-red)](https://dashboard.ngrok.com/get-started/your-authtoken)
Ngroktoken = "" #@param {type:"string"}
Prune = False  #@param {type:"boolean"}
NoLibrary = False  #@param {type:"boolean"}
DeforumMode = False  #@param {type:"boolean"}
SwapVersion = False  #@param {type:"boolean"}
QRControlnet = False  #@param {type:"boolean"}
PhotoshopAPI = False  #@param {type:"boolean"}

from google.colab import drive
drive.mount('/content/drive')

from IPython.display import clear_output
from IPython.utils import capture
from subprocess import getoutput
import ipywidgets as widgets
import sys
import fileinput
import os
import time
import subprocess
hf_token = "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"
user_header = f'"Authorization: Bearer {hf_token}"'

#install
# %cd /content

# !wget https://huggingface.co/phamhungd/SDVNColab/resolve/main/command.txt -qq
with open("/content/command.txt", "r") as file:
    commands = file.readlines()
for command in commands :
  subprocess.run(command,shell=True)
with open("/content/command/start.txt", "r") as file:
    commands = file.readlines()
with open("/content/command/sdvn.txt", "r") as file:
    sdvn = file.readlines()

lines=[0,1,2,3,4]
for line in lines :
  exec(commands[line])

#Library
if Version != "Kohya" :
  sample= !ls /content/drive/MyDrive/SD-Data/Setting15/configxl.json
  if sample == ["ls: cannot access '/content/drive/MyDrive/SD-Data/Setting15/configxl.json': No such file or directory"] :
    print("Khởi tạo thư mục lần đầu")
    lines=[35,36,37,38,39,40,41,42,43,46,50,81,82,83]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)

  with open("/content/command/sdvn.txt", "r") as file:
      sdvn = file.readlines()
  if Prune == True and Version != "SDXL" :
    lines=[8,52,59,60]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
  else :
      subprocess.run(sdvn[52],shell=True)
  if Prune == False and Version != "SDXL" :
    lines=[9,51,52,59,60]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
    if Controlnet == "Extra" :
      subprocess.run(sdvn[10],shell=True)
  else :
      subprocess.run(sdvn[52],shell=True)

#A1111

if Version != "ComfyUI" and Version != "Kohya" :
  # !rm -r /content/ComfyUI
  # %env TF_CPP_MIN_LOG_LEVEL=1
  subprocess.run(commands[6],shell=True)
  subprocess.run(commands[7],shell=True)
  # %env LD_PRELOAD=/content/libtcmalloc_minimal.so.4

  if Version == "A-1.3" :
      subprocess.run(commands[9],shell=True)
      subprocess.run(commands[10],shell=True)

  if Version=="SDXL" :
      SwapVersion = True
      Prune = True
      QRControlnet = False
      NoLibrary = True

  if SwapVersion == True :
    # !rm -r /content/SDVN
  with open("/content/command/sdvn.txt", "r") as file:
      sdvn = file.readlines()

  if Version=="A-1.3" :
      subprocess.run(sdvn[2],shell=True)
  if Version=="A-1.41" :
      subprocess.run(sdvn[3],shell=True)
  if Version=="A1111-update" :
      subprocess.run(sdvn[11],shell=True)
  if Version=="SDXL" :
      subprocess.run(sdvn[11],shell=True)
      # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M  https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0_0.9vae.safetensors -d /content/SDVN/models/Stable-diffusion -o SDXL-1.0.safetensors
  if Prune == True :
    with open("/content/command/baseprund.txt", "r") as file:
      exs = file.readlines()
      if Version != "SDXL" :
        for ex in exs :
          subprocess.run(ex,shell=True)
      else :
        lines = [4,5,8]
        for line in lines :
          subprocess.run(exs[line],shell=True)
        subprocess.run(sdvn[128],shell=True)
  else :
    with open("/content/command/exbase.txt", "r") as file:
      exs = file.readlines()
      for ex in exs :
        subprocess.run(ex,shell=True)

  if Extensions=="plus" :
    with open("/content/command/explus.txt", "r") as file:
      exs = file.readlines()
    for ex in exs :
      subprocess.run(ex,shell=True)

  if Extensions=="video" :
    with open("/content/command/exvideo.txt", "r") as file:
      exs = file.readlines()
    for ex in exs :
      subprocess.run(ex,shell=True)

  if Extensions=="train" :
    with open("/content/command/extrain.txt", "r") as file:
      exs = file.readlines()
    for ex in exs :
      subprocess.run(ex,shell=True)

  if DeforumMode == True and Extensions == "video":
    lines=[71,72,73,74,75,76,77,78,79]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
  if PhotoshopAPI == True :
    # !git clone https://github.com/AbdullahAlfaraj/Auto-Photoshop-StableDiffusion-Plugin.git /content/SDVN/extensions/Auto-Photoshop

  # %cd /content/SDVN

  #Controlnet
  if Version != "SDVN" :
    # !{sdvn[10]}
    if Controlnet == "Extra" :
      # !{sdvn[13]}

  if QRControlnet == True :
    # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/DionTimmer/controlnet_qrcode-control_v1p_sd15/resolve/main/control_v1p_sd15_qrcode.safetensors -d /content/Basecontrolnet/Base11 -o QRcode.safetensors
    # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/DionTimmer/controlnet_qrcode-control_v1p_sd15/resolve/main/control_v1p_sd15_qrcode.yaml -d /content/Basecontrolnet/Base11 -o QRcode.yaml
    # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/monster-labs/control_v1p_sd15_qrcode_monster/resolve/main/control_v1p_sd15_qrcode_monster.safetensors -d /content/Basecontrolnet/Base11 -o QRcode-monster.safetensors
    # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/monster-labs/control_v1p_sd15_qrcode_monster/resolve/main/control_v1p_sd15_qrcode_monster.yaml -d /content/Basecontrolnet/Base11 -o QRcode-monster.yaml
    # !aria2c --continue --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/111973 -d /content/Basecontrolnet/Base11 -o QRcode-Pattern.safetensors
    # !{sdvn[127]}
  # Library

  lines=[15,16,17,18,19,20,22]
  for line in lines :
    subprocess.run(sdvn[line],shell=True)
  if Version !="SDXL" :
    subprocess.run(sdvn[21],shell=True)
  else :
    subprocess.run(sdvn[30],shell=True)

  if Version=="A1111-update" or Version=="SDXL":
    lines=[23,24,25,26,27,28,29]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)

  #Custom

  lines=[33]
  for line in lines :
    subprocess.run(sdvn[line],shell=True)

  if Setting == "update" :
    print("Update tệp style")
    lines=[44,45]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)

  if Setting == "resetall" :
    print("Reset all setting file")
    lines=[47,48,49,81]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
  if NoLibrary==False and Prune==False:
    lines=[53,54,55,56,57,58,61,62]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
  else:
    lines=[53,54,55,57]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
  if Version == "SDXL" :
    subprocess.run(sdvn[85],shell=True)
    subprocess.run(sdvn[86],shell=True)

#ComfyUI

if Version == "ComfyUI" :
  print('[1;32mCài đặt ComfyUI...')
  time.sleep(4)
  with capture.capture_output() as cap:
    def inf(msg, style, wdth):
        inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth))
        display(inf)
    # !rm -r /content/SDVN
    lines=[88,89,90]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
    # %cd /content
    subprocess.run(sdvn[92],shell=True)
    # %cd /content/ComfyUI
    subprocess.run(sdvn[94],shell=True)
    # %cd /content/ComfyUI/custom_nodes

    lines=[96,97,98,99,100,102,103,104,105,126,130,131,132,133]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)

    # %cd /content/ComfyUI/custom_nodes/ComfyUI-Impact-Pack
    subprocess.run(sdvn[106],shell=True)
    # %cd /content/ComfyUI/custom_nodes/comfy_controlnet_preprocessors
    subprocess.run(sdvn[108],shell=True)
    # %cd /content/

    lines=[110,111,112,113,114,115,116,117,118]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)

    if Controlnet == "base" :
      subprocess.run(sdvn[120],shell=True)
    else :
      subprocess.run(sdvn[120],shell=True)
      subprocess.run(sdvn[121],shell=True)

    lines=[123,124]
    for line in lines :
      subprocess.run(sdvn[line],shell=True)
    # !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O /content/cloudflared-linux-amd64 && chmod 777 /content/cloudflared-linux-amd64
    # %cd /content/ComfyUI

  clear_output()
  inf('\u2714 Done','success', '150px')

if Version == "Kohya" :
  from google.colab import drive
  drive.mount('/content/drive')
  print('[1;32mCài đặt Kohya...')
  time.sleep(4)
  with capture.capture_output() as cap:
    def inf(msg, style, wdth):
        inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth))
        display(inf)
    # !pip install dadaptation==3.1 diffusers[torch]==0.17.1 easygui==0.98.3 einops==0.6.0 fairscale==0.4.13 ftfy==6.1.1 gradio==3.36.1 huggingface-hub==0.14.1
    # !pip install lion-pytorch==0.0.6 lycoris_lora==1.8.0.dev6 open-clip-torch==2.20.0 prodigyopt==1.0 pytorch-lightning==1.9.0 safetensors==0.3.1 timm==0.6.12
    # !pip install tk==0.1.0 transformers==4.30.2 voluptuous==0.13.1 wandb==0.15.0 xformers==0.0.20 omegaconf

    # %cd /content
    # !git clone -b 0.40.0 https://github.com/TimDettmers/bitsandbytes
    # %cd /content/bitsandbytes
    # !CUDA_VERSION=118 make cuda11x
    # !python setup.py install

    # %cd /content
    # !git clone https://github.com/bmaltais/kohya_ss
    # %cd /content/kohya_ss
  clear_output()
  inf('\u2714 Done','success', '150px')

#@markdown <br> [![](https://img.shields.io/badge/Info-Model-blue)](https://bit.ly/42Csmn7)

#Model
#@markdown ## ⚡️ Custom Model

SaveFromMyDrive = False  #@param {type:"boolean"}

if Version != "ComfyUI" and Version != "Kohya":
  checkpointpatch = "/content/SDVN/models/Stable-diffusion"
if Version == "ComfyUI" :
  checkpointpatch = "/content/ComfyUI/models/checkpoints"
if Version == "Kohya" :
  checkpointpatch = "/content/model"
if SaveFromMyDrive == True :
  checkpointpatch = "/content/drive/MyDrive/SD-Data/Model/"

CheckpointDownloadLink = "" #@param {type:"string"}
if CheckpointDownloadLink != "" :
  # %cd {checkpointpatch}
  # !wget {CheckpointDownloadLink} --content-disposition
  if Version != "ComfyUI" and Version != "Kohya":
    # %cd /content/SDVN
  if Version == "ComfyUI" :
    # %cd /content/ComfyUI
  if Version == "Kohya" :
    # %cd /content/kohya_ss

vnmodelUrl = ["",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/109869 -d {checkpointpatch} -o SDVN1-Real.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/110396 -d {checkpointpatch} -o SDVN2-RealRPG.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/110538 -d {checkpointpatch} -o SDVN3-RealArt-plus.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/110442 -d {checkpointpatch} -o SDVN4-3DCuteVN.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/110455 -d {checkpointpatch} -o SDVN5-3DCuteWave.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/130249 -d {checkpointpatch} -o SDVN6-RealXL.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/50765 -d {checkpointpatch} -o Duchaiten-GODofSIMP.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/63193 -d {checkpointpatch} -o Duchaiten-Darkside.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/80635 -d {checkpointpatch} -o Duchaiten-NijiCute.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/47085 -d {checkpointpatch} -o Duchaiten-StyleLikeMy.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/123949 -d {checkpointpatch} -o Duchaiten-Retro.safetensors"]
vnmodelList = ["",
              "SDVN1-Real",
              "SDVN2-RealRPG",
              "SDVN3-RealArt-plus",
              "SDVN4-3DCuteVN",
              "SDVN5-3DCuteWave",
              "SDVN6-RealXL",
              "Duchaiten-GODofSIMP",
              "Duchaiten-Darkside",
              "Duchaiten-NijiCute",
              "Duchaiten-StyleLikeMy",
              "Duchaiten-Retro"]
#@markdown ## 👨🏻‍💻 VN Model
vnmodel = ""  #@param ["", "SDVN1-Real", "SDVN2-RealRPG", "SDVN3-RealArt-plus", "SDVN4-3DCuteVN", "SDVN5-3DCuteWave", "SDVN6-RealXL", "Duchaiten-GODofSIMP", "Duchaiten-Darkside", "Duchaiten-NijiCute", "Duchaiten-StyleLikeMy", "Duchaiten-Retro"]
# !{vnmodelUrl[vnmodelList.index(vnmodel)]}
baseUrl = ["",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt -d {checkpointpatch} -o StableDiffusion-v14.ckpt",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned.safetensors -d {checkpointpatch} -o StableDiffusion-v15.safetensors",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/v2-1_512-nonema-pruned.safetensors -d {checkpointpatch} -o StableDiffusion-v21-512.safetensors",
          f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-nonema-pruned.safetensors -d {checkpointpatch} -o StableDiffusion-v21-768.safetensors",
          f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M  https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0_0.9vae.safetensors -d {checkpointpatch} -o SDXL-1.0.safetensors"]
baseList = ["",
            "StableDiffusion-v14",
            "StableDiffusion-v15",
            "StableDiffusion-v21-512",
            "StableDiffusion-v21-768",
            "SDXL-Base-1.0"]
#@markdown ## 🎇 Base Model
basemodelName = ""  #@param ["", "StableDiffusion-v14","StableDiffusion-v15", "StableDiffusion-v21-512",  "StableDiffusion-v21-768", "SDXL-Base-1.0"]
# !{baseUrl[baseList.index(basemodelName)]}
modelUrl = ["",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/9474 -d {checkpointpatch} -o Chilloutmix.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/130072 -d {checkpointpatch} -o RealisticVision51.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/15236 -d {checkpointpatch} -o Deliberate.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/128713 -d {checkpointpatch} -o DreamShaperv8.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/79290 -d {checkpointpatch} -o A-ZovyaRPGv3.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/70458 -d {checkpointpatch} -o HenmixRealv4.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/77784 -d {checkpointpatch} -o Fantasticv65.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/77903 -d {checkpointpatch} -o XXMix_9realisticv3.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/94640 -d {checkpointpatch} -o MajicmixRealv6.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/46846 -d {checkpointpatch} -o ReVAnimatedv122.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/88158 -d {checkpointpatch} -o RunDiffusionFXv1.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/113479 -d {checkpointpatch} -o RBeautifulRealAsiansv6.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/113623 -d {checkpointpatch} -o LEOSAM-MoonFilm-v2.safetensors"]
modelList = ["",
             "Chilloutmix",
             "RealisticVision51",
             "Deliberate",
             "DreamShaperv8",
             "A-ZovyaRPGv3",
             "HenmixRealv4",
             "Fantasticv65",
             "XXMix_9realisticv3",
             "MajicmixRealv6",
             "ReVAnimatedv122",
             "RunDiffusionFXv1",
             "RBeautifulRealAsiansv6",
             "LEOSAM-MoonFilm-v2"]
#@markdown ## 🏞️ Realistic model 1
modelName = ""  #@param ["", "Chilloutmix", "RealisticVision51", "Deliberate", "DreamShaperv8", "A-ZovyaRPGv3", "HenmixRealv4", "Fantasticv65", "XXMix_9realisticv3", "MajicmixRealv6", "ReVAnimatedv122", "RunDiffusionFXv1", "RBeautifulRealAsiansv6", "LEOSAM-MoonFilm-v2"]
# !{modelUrl[modelList.index(modelName)]}


model2Url = ["",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/7425 -d {checkpointpatch} -o Counterfeit.safetensors",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/OtakupastelwaveMixPro/resolve/main/OtakuMix.safetensors -d {checkpointpatch} -o OtakupastelwaveMixPro.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/xyn-ai/anything-v4.0/resolve/main/anything-v4.5-pruned-fp16.ckpt -d {checkpointpatch} -o AnythingV45.ckpt",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/StableDiffusionVN/resolve/main/Dalcefov4.safetensors -d {checkpointpatch} -o Dalcefov4.safetensors",
            f"aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -s 16 -k 1M https://huggingface.co/phamhungd/StableDiffusionVN/resolve/main/Camelliamix.safetensors -d {checkpointpatch} -o Camelliamix.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/27424 -d {checkpointpatch} -o FishMix.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/19348 -d {checkpointpatch} -o OrientalMix.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/36473 -d {checkpointpatch} -o ThreeDelicacyv2.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/50765 -d {checkpointpatch} -o GODofSIMP.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/17028 -d {checkpointpatch} -o TheoldfishSpread.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/40101 -d {checkpointpatch} -o Theoldfish.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/14835 -d {checkpointpatch} -o NightSkyYOZORA.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/76907 -d {checkpointpatch} -o GhostMixv2.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/125771 -d {checkpointpatch} -o ToonYou-beta6.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/88516 -d {checkpointpatch} -o ComicsArthemyv3.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/88516 -d {checkpointpatch} -o MeinaMix-v11.safetensors",
            f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/116017 -d {checkpointpatch} -o ManmaruMix-v2.safetensors"]
model2List = ["",
             "Counterfeit",
             "OtakupastelwaveMix",
             "AnythingV45",
             "Dalcefov4",
             "Camelliamix",
             "OrientalMix",
             "FishMix",
             "ThreeDelicacyv2",
             "GODofSIMP",
             "TheoldfishSpread",
             "Theoldfish",
             "NightSkyYOZORA",
             "GhostMixv2",
             "ToonYou-beta6",
             "ComicsArthemyv3",
             "MeinaMix-v11",
             "ManmaruMix-v2"]
#@markdown ## 🌇 Anime/Paint model 2
model2Name = ""  #@param ["", "Counterfeit", "OtakupastelwaveMix", "AnythingV45", "Dalcefov4", "Camelliamix", "OrientalMix", "FishMix", "ThreeDelicacyv2", "GODofSIMP", "TheoldfishSpread", "Theoldfish", "NightSkyYOZORA", "GhostMixv2", "ToonYou-beta6", "ComicsArthemyv3", "MeinaMix-v11", "ManmaruMix-v2"]
# !{model2Url[model2List.index(model2Name)]}

# %%
#@title # ⌛️ 2.RUN
SDXLMode = False  #@param {type:"boolean"}
if Version !="A1111-update" :
  SDXLMode = False
if Version != "ComfyUI" and Version != "Kohya":
  print('[1;32mCài đặt Extension tuỳ chọn...')
  time.sleep(4)
  with capture.capture_output() as cap:
    def inf(msg, style, wdth):
        inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth))
        display(inf)
    # %cd /content/SDVN/extensions
    with open("/content/drive/MyDrive/SD-Data/wildcards/MyExtensionList.txt", "r") as file:
      lists = file.readlines()
    for list in lists :
      # !git clone {list}
    # %cd /content/SDVN

  clear_output()
  inf('\u2714 Done','success', '150px')

  with open("/content/drive/MyDrive/SD-Data/wildcards/Ngroktoken.txt", "r") as file:
      lists = file.readlines()
  if Ngroktoken != "" :
    token = Ngroktoken
  else :
    if lists !=[]:
      token = lists[0]
    else :
      token = "sdvn"
  if Version=="SDXL" or SDXLMode == True :
    # !python launch.py --api --share --theme dark --xformers --enable-insecure-extension-access --disable-safe-unpickle \
    --ui-settings-file /content/drive/MyDrive/SD-Data/Setting15/configxl.json --styles-file /content/drive/MyDrive/SD-Data/Setting15/styles.csv \
    --ckpt-dir /content/drive/MyDrive/SD-Data/Model \
    --lora-dir /content/drive/MyDrive/SD-Data/Lora \
    --ngrok {token}
  else :
    if token == "sdvn" :
      # !python launch.py --api --share --theme dark --xformers --enable-insecure-extension-access --disable-safe-unpickle\
        --ui-settings-file /content/drive/MyDrive/SD-Data/Setting15/config.json --styles-file /content/drive/MyDrive/SD-Data/Setting15/styles.csv \
        --ckpt-dir /content/drive/MyDrive/SD-Data/Model \
        --lora-dir /content/drive/MyDrive/SD-Data/Lora --lyco-dir /content/drive/MyDrive/SD-Data/Lyco \
        --embeddings-dir /content/drive/MyDrive/SD-Data/Embeddings --hypernetwork-dir /content/drive/MyDrive/SD-Data/Hypernetworks
    else :
      # !python launch.py --api --share --theme dark --xformers --enable-insecure-extension-access --disable-safe-unpickle\
        --ui-settings-file /content/drive/MyDrive/SD-Data/Setting15/config.json --styles-file /content/drive/MyDrive/SD-Data/Setting15/styles.csv \
        --ckpt-dir /content/drive/MyDrive/SD-Data/Model \
        --lora-dir /content/drive/MyDrive/SD-Data/Lora --lyco-dir /content/drive/MyDrive/SD-Data/Lyco \
        --embeddings-dir /content/drive/MyDrive/SD-Data/Embeddings --hypernetwork-dir /content/drive/MyDrive/SD-Data/Hypernetworks \
        --ngrok {token}
if Version == "ComfyUI" :
  print("Truy cập đường link bên dưới để sử dụng (Link sử dụng được sau khi hiện thông báo - Import times for custom nodes:- )")
  import atexit, requests, subprocess, time, re, os
  from random import randint
  from threading import Timer
  from queue import Queue
  def cloudflared(port, metrics_port, output_queue):
      atexit.register(lambda p: p.terminate(), subprocess.Popen(['/content/cloudflared-linux-amd64', 'tunnel', '--url', f'http://127.0.0.1:{port}', '--metrics', f'127.0.0.1:{metrics_port}'], stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT))
      attempts, tunnel_url = 0, None
      while attempts < 10 and not tunnel_url:
          attempts += 1
          time.sleep(3)
          try:
              tunnel_url = re.search("(?P<url>https?:\/\/[^\s]+.trycloudflare.com)", requests.get(f'http://127.0.0.1:{metrics_port}/metrics').text).group("url")
          except:
              pass
      if not tunnel_url:
          raise Exception("Can't connect to Cloudflare Edge")
      output_queue.put(tunnel_url)
  output_queue, metrics_port = Queue(), randint(8100, 9000)
  thread = Timer(2, cloudflared, args=(8188, metrics_port, output_queue))
  thread.start()
  thread.join()
  tunnel_url = output_queue.get()
  os.environ['webui_url'] = tunnel_url
  print(tunnel_url)
  # !python main.py --dont-print-server

if Version == "Kohya" :
  # !python kohya_gui.py --share --headless
